# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread(filename='page_5_img.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(9,16))
plt.imshow(image)
plt.show()

# %%
plt.imshow(gray)
plt.show()

# %%
plt.imshow(image,cmap='gray')
plt.show()

# %%
# load the image as a PIL/Pillow image, apply OCR, and then delete
# the temporary file
text = pytesseract.image_to_string(Image.open('./test_image1.png'))
print(text)
# Out:
# SLO RES ee, SSE LES LE oo4a/ooa
#
# © 42-30-2019 §:27 PM Fax Services + 12124217207 Pa tors
#
# 1. Patient does not have access to outpatient hospital services and is debilitated euch that transport le a physical hardship
# 2. Patient has other musculoskeletal condition that directly impacts rate of recovery
#
# 3. Patient requires treatment to reduce ADL assistance
#
# Rehab Potential: Excellent.
#
# Seals
#
# Pain
# Patient will report pain level 1/10 with activity,
# goal was established on 12-30-19
#
# Eostur,
#
# Patients standing posture will present with in order to improve functional standing posture, In 90 days.
# Wall Occiput Measure Will measure: 3 centimeters.
#
# This goal was established on 12-30-19.
#
# Gait and
#
# Patient will ambulate on level and unlevel surface for 500.00 feet with no AD, independently in 80 days. This goal was
# established on 12-30-19.
#
# ...

# %%
img = cv2.resize(image, None, fx=2.5, fy=2.5, interpolation=cv2.INTER_LINEAR)

# %%
plt.figure(figsize=(9,16))
plt.imshow(img)
plt.show()

# %%
save_img = cv2.imwrite('/home/bilal/pandas/OCR/tesseract-ocr/processed_image.png',img)

# %%
text = pytesseract.image_to_string(Image.open('/home/bilal/pandas/OCR/tesseract-ocr/processed_image.png'))
print(text)
# Out:
# O1l/YoOo2/20 20 THU iaite)eitt FAx WwIooda/vood
#
# &> £2-30-2019 S:27 PM Fax Services > 12124217207 Pa + of 5
#
# 1. Patient does not have access to outpatient hospital services and is debilitated Such that transport ic a physical hardship
# 2. Patient has other musculoskeletal condition that directly trnpacts rate of recovery
#
# 3. Patient recquuires treatment to reduce ADL assistance
#
# Rehab Potential; Excellent.
#
# Goals
#
# Pain
#
# Patient willl report pain level 1/10 with activity, in Lower back, hips, knees im order ta walk with minimal pain, in 90 days. This
# goalwas established on 12-30-1923
#
# Posture
#
# Patient's standing posture will present with In order to itmprove functional standing posture, In 30 days.
#
# Veal Occiput Measure will measure: 3 centimeters.
#
# This gpoalwas established on 12-30-19.
#
# Sait and Stair Mobility
#
# Patient will ambulate on level and unlevel surface for 500.00 feet with no AD, independently in 80 days. This goal was
# ...

# %%
from autocorrect import Speller
spell = Speller(lang='en')
print(spell(text))
# Out:
# O1l/Yoo2/20 20 HU date)litt Fix Wwoods/good
#
# &> £2-30-2019 S:27 Px Fax Services > 12124217207 Pa + of 5
#
# 1. Patient does not have access to outpatient hospital services and is debilitated Such that transport ic a physical hardship
# 2. Patient has other musculoskeletal condition that directly tracts rate of recovery
#
# 3. Patient requires treatment to reduce DL assistance
#
# Rehab Potential; Excellent.
#
# Goals
#
# Pain
#
# Patient will report pain level 1/10 with activity, in Lower back, hips, knees im order ta walk with minimal pain, in 90 days. This
# goals established on 12-30-1923
#
# Posture
#
# Patient's standing posture will present with In order to improve functional standing posture, In 30 days.
#
# Real Occiput Measure will measure: 3 centimeters.
#
# This gpoalwas established on 12-30-19.
#
# Said and Stair Mobility
#
# Patient will ambulance on level and level surface for 500.00 feet with no A, independently in 80 days. This goal was
# established on 12-30-19.
# ...
